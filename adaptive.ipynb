# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/chromatix-team/chromatix/blob/main/docs/examples/fourier_ptychography.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# If in Colab, install Chromatix. Don't forget to select a GPU!
# %pip install --upgrade pip
# %pip install "git+https://github.com/chromatix-team/chromatix.git"
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-26.1-py3-none-any.whl.metadata (4.6 kB)
# Downloading pip-26.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 14.0 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-26.1
# Collecting git+https://github.com/chromatix-team/chromatix.git
#   Cloning https://github.com/chromatix-team/chromatix.git to /tmp/pip-req-build-eqnyzb_j
#   Running command git clone --filter=blob:none --quiet https://github.com/chromatix-team/chromatix.git /tmp/pip-req-build-eqnyzb_j
#   Resolved https://github.com/chromatix-team/chromatix.git to commit a607a9f192e873e52632d8e16bdb8bb12a00aaa0
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: jax>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from chromatix==0.5.0) (0.7.2)
# Requirement already satisfied: einops>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from chromatix==0.5.0) (0.8.2)
# Collecting chex>=0.1.5 (from chromatix==0.5.0)
#   Downloading chex-0.1.91-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: optax>=0.1.4 in /usr/local/lib/python3.12/dist-packages (from chromatix==0.5.0) (0.2.8)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from chromatix==0.5.0) (1.16.3)
# Collecting jaxopt>=0.8.5 (from chromatix==0.5.0)
#   Downloading jaxopt-0.8.5-py3-none-any.whl.metadata (3.3 kB)
# Collecting jaxtyping>=0.3.3 (from chromatix==0.5.0)
#   Downloading jaxtyping-0.3.9-py3-none-any.whl.metadata (7.4 kB)
# Collecting equinox>=0.12.2 (from chromatix==0.5.0)
#   Downloading equinox-0.13.7-py3-none-any.whl.metadata (18 kB)
# Collecting optimistix>=0.0.10 (from chromatix==0.5.0)
#   Downloading optimistix-0.1.0-py3-none-any.whl.metadata (18 kB)
# Collecting absl-py>=2.3.1 (from chex>=0.1.5->chromatix==0.5.0)
#   Downloading absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: typing_extensions>=4.15.0 in /usr/local/lib/python3.12/dist-packages (from chex>=0.1.5->chromatix==0.5.0) (4.15.0)
# Requirement already satisfied: jaxlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from chex>=0.1.5->chromatix==0.5.0) (0.7.2)
# Requirement already satisfied: numpy>=1.24.1 in /usr/local/lib/python3.12/dist-packages (from chex>=0.1.5->chromatix==0.5.0) (2.0.2)
# Collecting toolz>=1.0.0 (from chex>=0.1.5->chromatix==0.5.0)
#   Downloading toolz-1.1.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting wadler-lindig>=0.1.0 (from equinox>=0.12.2->chromatix==0.5.0)
#   Downloading wadler_lindig-0.1.7-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from jax>=0.4.1->chromatix==0.5.0) (0.5.4)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax>=0.4.1->chromatix==0.5.0) (3.4.0)
# Collecting lineax>=0.0.6 (from optimistix>=0.0.10->chromatix==0.5.0)
#   Downloading lineax-0.1.0-py3-none-any.whl.metadata (18 kB)
# Downloading chex-0.1.91-py3-none-any.whl (100 kB)
# Downloading absl_py-2.4.0-py3-none-any.whl (135 kB)
# Downloading equinox-0.13.7-py3-none-any.whl (182 kB)
# Downloading jaxopt-0.8.5-py3-none-any.whl (172 kB)
# Downloading jaxtyping-0.3.9-py3-none-any.whl (56 kB)
# Downloading optimistix-0.1.0-py3-none-any.whl (101 kB)
# Downloading lineax-0.1.0-py3-none-any.whl (74 kB)
# Downloading toolz-1.1.0-py3-none-any.whl (58 kB)
# Downloading wadler_lindig-0.1.7-py3-none-any.whl (20 kB)
# Building wheels for collected packages: chromatix
#   Building wheel for chromatix (pyproject.toml) ... done
#   Created wheel for chromatix: filename=chromatix-0.5.0-py3-none-any.whl size=99756 sha256=fc3d26ec438d35ea3eb673c1aff316876e23858cc71d299b56428c38c4de8126
#   Stored in directory: /tmp/pip-ephem-wheel-cache-sl2lee8v/wheels/ce/85/53/704a07eec0be6c125acf5a6d57082c10d3a3787dcf05cd8811
# Successfully built chromatix
# Installing collected packages: wadler-lindig, toolz, absl-py, jaxtyping, jaxopt, equinox, chex, lineax, optimistix, chromatix
#   Attempting uninstall: toolz
#     Found existing installation: toolz 0.12.1
#     Uninstalling toolz-0.12.1:
#       Successfully uninstalled toolz-0.12.1
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.4.0
#     Uninstalling absl-py-1.4.0:
#       Successfully uninstalled absl-py-1.4.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [chromatix]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ibis-framework 9.5.0 requires toolz<1,>=0.11, but you have toolz 1.1.0 which is incompatible.
# Successfully installed absl-py-2.4.0 chex-0.1.91 chromatix-0.5.0 equinox-0.13.7 jaxopt-0.8.5 jaxtyping-0.3.9 lineax-0.1.0 optimistix-0.1.0 toolz-1.1.0 wadler-lindig-0.1.7

# %%
from typing import Any

import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
import numpy as np
import optax
import skimage
from einops import rearrange
from jaxtyping import Array

import chromatix.functional as cx

# %% [markdown]
# ## Display Utility Functions
#
# These cells define functions that we will use to display our results. Make sure to run these to define these functions, but otherwise you won't need to touch these functions.

# %%
def show_amplitude_and_phase(amplitude: np.ndarray, phase: np.ndarray):
    fig, axes = plt.subplots(nrows=1, ncols=2, dpi=300)
    ax = axes[0]
    ax.imshow(amplitude, cmap="gray")
    ax.axis("off")
    ax.set_title("amplitude")
    ax = axes[1]
    ax.imshow(phase, cmap="hsv")
    ax.axis("off")
    ax.set_title("phase")

# %%
def show_image(image: np.ndarray):
    fig = plt.figure(dpi=150)
    ax = fig.gca()
    ax.imshow(image, cmap="gray")
    ax.axis("off")
    ax.set_title("image")

# %%
def plot_losses(losses: np.ndarray, num_iterations: int):
    fig = plt.figure(dpi=150)
    ax = fig.gca()
    ax.plot(np.log(np.mean(np.array(np.array_split(losses, num_iterations)), axis=1)))
    ax.set_title("optimization")
    ax.set_ylabel("loss")
    ax.set_xlabel("iteration")

# %%
def compute_importance(parameters, images, kykx):
    amplitude, phase = parameters

    def single_importance(image, k):
        simulated = tilted_illumination_system(amplitude, phase, k)
        return jnp.mean((simulated - image) ** 2)

    # vectorize over all images
    scores = jax.vmap(single_importance)(images, kykx)

    return scores

# %%
def select_top_k(scores, k):
    scores_np = np.array(scores)
    indices = np.argsort(-scores_np)  # descending
    return indices[:k]

# %%
def tv_loss(x):
    dx = jnp.diff(x, axis=0)
    dy = jnp.diff(x, axis=1)
    return jnp.mean(jnp.sqrt(dx**2 + 1e-8)) + jnp.mean(jnp.sqrt(dy**2 + 1e-8))

# %%
def log_tv_prior(amplitude):
    amp = jnp.log(amplitude + 1e-8)
    return tv_loss(amp)

# %% [markdown]
# ## Fourier Ptychography Basics
#
# Fourier ptychography is a computational optics technique that allows you to obtain resolution higher than the diffraction limited resolution of your microscope, while also recovering the complex field (amplitude and phase) of your sample. You can extend the basic concept of Fourier ptychography for many other applications, including recovering 3D phase for multiple scattering samples ([Chowdhury et al.](https://opg.optica.org/optica/fulltext.cfm?uri=optica-6-9-1211&id=418751)).
#
# In Fourier ptychography, you convolve the pupil of the imaging system in the Fourier plane by illuminating the sample with a tilted plane wave. As you take multiple images with different tilts, each image gives you different information about the amplitude and phase content of your sample, as well as captures higher frequencies from the sample that would otherwise be cut off by the limited pupil of the microscope (defined by its numerical aperture), as shown in the diagram below.
#
# In order to perform Fourier ptychography, we first need to model a microscope with coherent, tilted illumination.
#
# ![image.png](data:image/png;base64,...)
#
# (Image from [https://doi.org/10.1364/OE.386168](https://doi.org/10.1364/OE.386168))

# %% [markdown]
# ## Modeling Tilted Illumination Microscope
#
# The microscope we want to model illuminates the amplitude and phase sample with tilted plane waves, relays the sample to the camera plane through a 4f system with limited NA to simulate the limited resolution of a real microscope, and then captures the intensity at the camera plane. Note that every step listed below just corresponds to just 1 or 2 lines of code using the corresponding function(s) from Chromatix!

# %%
def tilted_illumination_system(amplitude: Array, phase: Array, kykx: Array) -> Array:
    # 1. Start with an angled plane wave for illumination.
    # The angle is defined by a shift in Fourier (k) space, given by the kykx vector.
    # You will want to create a field with the same shape as the sample (512, 512) with
    # a pixel spacing (sampling) of 0.3 microns, and a single wavelength of 0.532 microns
    field = cx.plane_wave(amplitude.shape, 0.3, 0.532, kykx=kykx)
    # 2. Apply the amplitude of the sample to the incoming illumination field.
    field = cx.amplitude_change(field, amplitude)
    # 3. Apply the phase of the sample to the incoming field.
    field = cx.phase_change(field, phase)
    # 4. Define a 4f system to relay the illuminated sample to the camera plane!
    # You will want to use the same focal length for both lenses in this demo (1.8e3 microns),
    # with a refractive index of 1.33 and an NA in the pupil plane of 0.3.
    field = cx.ff_lens(field, 1.8e3, 1.33)
    field = cx.ff_lens(field, 1.8e3, 1.33, NA=0.3)
    # 5. Return the intensity of the field at the camera plane, since we measure intensity.
    return field.intensity

# %% [markdown]
# Next, we'll need to create a "sample" that we can pretend to measure with tilted illuminations. Here we'll use some default datasets from skimage.

# %%
amplitude = skimage.data.camera().astype("float")
amplitude = amplitude / amplitude.max()
phase = skimage.data.moon().astype("float")
phase = np.pi * phase / phase.max()
show_amplitude_and_phase(amplitude, phase)

# %% [markdown]
# These next few lines simulate imaging the sample we just created above using 121 different angles of illumination. We'll need to capture many images at different angles of illumination to get enough information to constrain our inverse problem. You will also get an array of kykx vectors (`kykx`) that define the angle of each illumination. Normally these angles of illumination would be something you have to calibrate, but since we're simulating things we get these angles exactly. For this example, we'll pretend that these are our "measured" images.

# %%
kykx = (
    jnp.array(
        jnp.meshgrid(jnp.linspace(-0.5, 0.5, num=11), jnp.linspace(-0.5, 0.5, num=11))
    )
    * 2
    * jnp.pi
)
kykx = rearrange(kykx, "d h w -> (h w) d")
images = jax.vmap(
    lambda k: tilted_illumination_system(jnp.array(amplitude), jnp.array(phase), k)
)(kykx)

# %% [markdown]
# This should show you the "measured" image of the sample without any tilt, so you shouldn't see very much contribution from the phase of the sample. So this should look mostly like a blurry version of the camera man, because we imaged that sample with a low NA system.

# %%
show_image(images[60])

# %% [markdown]
# This should look like the amplitude sample, but with some "shadows" coming from the larger tilt of the illumination giving you some phase contrast.

# %%
show_image(images[65])

# %% [markdown]
# This should look like a dark field image of the sample, i.e. most of the amplitude of the sample (except the highest frequencies) should be missing from this image.

# %%
show_image(images[0])

# %% [markdown]
# ## Fourier Ptychography Reconstruction with Automatic Differentiation
#
# Here, we want to reconstruct the complex sample (amplitude and phase) at a higher resolution than we measured. While we could do this in the traditional Gerchberg-Saxton style algorithm for Fourier ptychography, here we'll take advantage of the fact that Chromatix is fully differentiable to perform this optimization. The hard part is already done, since we defined the forward model above!
#
# Now all we need to do is to define a loss function (mean squared error) between the "measured" images and our simulations using a guess of the reconstruction, and then use gradient descent optimization to reconstruct the complex sample.

# %%
# We're initializing the parameters that we want to optimize, i.e. the amplitude and phase of the sample.
parameters = (images[60][::-1, ::-1], jnp.zeros_like(images[60]))
# We also initialize an optimizer (in this case we're just performing gradient descent, so there's no optimizer state).
optimizer = optax.sgd(1e12)
opt_state = optimizer.init(parameters)


# This defines our loss function, and it takes in the parameters
# we want to take gradients with respect to as the first argument.
def loss_fn(parameters: Array, measured_image: Array, kykx: Array) -> Array:
    # 1. Extract the amplitude and phase from the parameters tuple.
    # Remember that the first element of the tuple is the amplitude and
    # the second element is the phase.
    amplitude = parameters[0]
    phase = parameters[1]
    # 2. Simulate imaging the amplitude and phase you just got using
    # the forward model we defined previously.
    simulated = tilted_illumination_system(amplitude, phase, kykx)
    # 3. Return the mean squared error between the simulated image of
    # our reconstruction and the "measured" image that we passed to
    # this loss function. WARNING: Make sure to squeeze the output of your
    # simulation! Otherwise you'll get weird broadcasting that creates a
    # huge array, giving you incorrect results and making things really slow.
    return jnp.mean((simulated - measured_image) ** 2)


# This defines the update step which computes the loss but also the gradient of the loss
# with respect to our parameters (i.e. our guess of the reconstructed sample). We then use
# that gradient and our optimizer to update our reconstruction.
@jax.jit
def update(
    parameters: tuple[Array, Array], opt_state: Any, image: Array, kykx: Array
) -> tuple[tuple[Array, Array], Any]:
    loss, grads = jax.value_and_grad(loss_fn)(parameters, image, kykx)
    updates, opt_state = optimizer.update(grads, opt_state)
    parameters = optax.apply_updates(parameters, updates)
    return loss, parameters, opt_state


# We then run this update step multiple times over all 121 measured images in order to arrive at a reconstruction.
# We've chosen the learning rate for you so that this should appropriately converge if everything's gone right.
losses = []
k = 40  # number of images to use (try 40–80)

for i in range(150):
    # 1. compute importance using current parameters
    scores = compute_importance(parameters, images, kykx)

    # 2. select most informative angles
    selected_indices = select_top_k(scores, k)

    # 3. train only on selected images
    for j in selected_indices:
        loss, parameters, opt_state = update(
            parameters, opt_state, images[j], kykx[j]
        )
        losses.append(np.array(loss))

    print(
        f"iteration {i+1}, using {k} images, "
        f"avg loss = {np.mean(losses[-k:])}"
    )

# scores = compute_importance(parameters, images, kykx)
# scores_np = np.array(scores)
# sorted_indices = np.argsort(-scores_np)  # descending (most important first)

# print("Top 10 most important indices:")
# print(sorted_indices[:10])

# print("Bottom 10 least important indices:")
# print(sorted_indices[-10:])

# importance_map = scores_np.reshape(11, 11)

# plt.imshow(importance_map, cmap='viridis')
# plt.colorbar()
# plt.title("Importance Map (higher = more useful)")
# plt.show()
# Out:
# iteration 1, using 40 images, avg loss = nan
# iteration 2, using 40 images, avg loss = nan
# iteration 3, using 40 images, avg loss = nan
# iteration 4, using 40 images, avg loss = nan
# iteration 5, using 40 images, avg loss = nan
# iteration 6, using 40 images, avg loss = nan
# iteration 7, using 40 images, avg loss = nan
# iteration 8, using 40 images, avg loss = nan
# iteration 9, using 40 images, avg loss = nan
# iteration 10, using 40 images, avg loss = nan
# iteration 11, using 40 images, avg loss = nan
# iteration 12, using 40 images, avg loss = nan
# iteration 13, using 40 images, avg loss = nan
# iteration 14, using 40 images, avg loss = nan
# iteration 15, using 40 images, avg loss = nan
# iteration 16, using 40 images, avg loss = nan
# iteration 17, using 40 images, avg loss = nan
# iteration 18, using 40 images, avg loss = nan
# iteration 19, using 40 images, avg loss = nan
# iteration 20, using 40 images, avg loss = nan
# iteration 21, using 40 images, avg loss = nan
# iteration 22, using 40 images, avg loss = nan
# iteration 23, using 40 images, avg loss = nan
# iteration 24, using 40 images, avg loss = nan
# iteration 25, using 40 images, avg loss = nan
# iteration 26, using 40 images, avg loss = nan
# iteration 27, using 40 images, avg loss = nan
# iteration 28, using 40 images, avg loss = nan
# iteration 29, using 40 images, avg loss = nan
# iteration 30, using 40 images, avg loss = nan
# iteration 31, using 40 images, avg loss = nan
# iteration 32, using 40 images, avg loss = nan
# iteration 33, using 40 images, avg loss = nan
# iteration 34, using 40 images, avg loss = nan
# iteration 35, using 40 images, avg loss = nan
# iteration 36, using 40 images, avg loss = nan
# iteration 37, using 40 images, avg loss = nan
# iteration 38, using 40 images, avg loss = nan
# iteration 39, using 40 images, avg loss = nan
# iteration 40, using 40 images, avg loss = nan
# iteration 41, using 40 images, avg loss = nan
# iteration 42, using 40 images, avg loss = nan
# iteration 43, using 40 images, avg loss = nan
# iteration 44, using 40 images, avg loss = nan
# iteration 45, using 40 images, avg loss = nan
# iteration 46, using 40 images, avg loss = nan
# iteration 47, using 40 images, avg loss = nan
# iteration 48, using 40 images, avg loss = nan
# iteration 49, using 40 images, avg loss = nan
# iteration 50, using 40 images, avg loss = nan
# iteration 51, using 40 images, avg loss = nan
# iteration 52, using 40 images, avg loss = nan
# iteration 53, using 40 images, avg loss = nan
# iteration 54, using 40 images, avg loss = nan
# iteration 55, using 40 images, avg loss = nan
# iteration 56, using 40 images, avg loss = nan
# iteration 57, using 40 images, avg loss = nan
# iteration 58, using 40 images, avg loss = nan
# iteration 59, using 40 images, avg loss = nan
# iteration 60, using 40 images, avg loss = nan
# iteration 61, using 40 images, avg loss = nan
# iteration 62, using 40 images, avg loss = nan
# iteration 63, using 40 images, avg loss = nan
# iteration 64, using 40 images, avg loss = nan
# iteration 65, using 40 images, avg loss = nan
# iteration 66, using 40 images, avg loss = nan
# iteration 67, using 40 images, avg loss = nan
# iteration 68, using 40 images, avg loss = nan
# iteration 69, using 40 images, avg loss = nan
# iteration 70, using 40 images, avg loss = nan
# iteration 71, using 40 images, avg loss = nan
# iteration 72, using 40 images, avg loss = nan
# iteration 73, using 40 images, avg loss = nan
# iteration 74, using 40 images, avg loss = nan
# iteration 75, using 40 images, avg loss = nan
# iteration 76, using 40 images, avg loss = nan
# iteration 77, using 40 images, avg loss = nan
# iteration 78, using 40 images, avg loss = nan
# iteration 79, using 40 images, avg loss = nan
# iteration 80, using 40 images, avg loss = nan
# iteration 81, using 40 images, avg loss = nan
# iteration 82, using 40 images, avg loss = nan
# iteration 83, using 40 images, avg loss = nan
# iteration 84, using 40 images, avg loss = nan
# iteration 85, using 40 images, avg loss = nan
# iteration 86, using 40 images, avg loss = nan
# iteration 87, using 40 images, avg loss = nan
# iteration 88, using 40 images, avg loss = nan
# iteration 89, using 40 images, avg loss = nan
# iteration 90, using 40 images, avg loss = nan
# iteration 91, using 40 images, avg loss = nan
# iteration 92, using 40 images, avg loss = nan
# iteration 93, using 40 images, avg loss = nan
# iteration 94, using 40 images, avg loss = nan
# iteration 95, using 40 images, avg loss = nan
# iteration 96, using 40 images, avg loss = nan
# iteration 97, using 40 images, avg loss = nan
# iteration 98, using 40 images, avg loss = nan
# iteration 99, using 40 images, avg loss = nan
# iteration 100, using 40 images, avg loss = nan
# iteration 101, using 40 images, avg loss = nan
# iteration 102, using 40 images, avg loss = nan
# iteration 103, using 40 images, avg loss = nan
# iteration 104, using 40 images, avg loss = nan
# iteration 105, using 40 images, avg loss = nan
# iteration 106, using 40 images, avg loss = nan
# iteration 107, using 40 images, avg loss = nan
# iteration 108, using 40 images, avg loss = nan
# iteration 109, using 40 images, avg loss = nan
# iteration 110, using 40 images, avg loss = nan
# iteration 111, using 40 images, avg loss = nan
# iteration 112, using 40 images, avg loss = nan
# iteration 113, using 40 images, avg loss = nan
# iteration 114, using 40 images, avg loss = nan
# iteration 115, using 40 images, avg loss = nan
# iteration 116, using 40 images, avg loss = nan
# iteration 117, using 40 images, avg loss = nan
# iteration 118, using 40 images, avg loss = nan
# iteration 119, using 40 images, avg loss = nan
# iteration 120, using 40 images, avg loss = nan
# iteration 121, using 40 images, avg loss = nan
# iteration 122, using 40 images, avg loss = nan
# iteration 123, using 40 images, avg loss = nan
# iteration 124, using 40 images, avg loss = nan
# iteration 125, using 40 images, avg loss = nan
# iteration 126, using 40 images, avg loss = nan
# iteration 127, using 40 images, avg loss = nan
# iteration 128, using 40 images, avg loss = nan
# iteration 129, using 40 images, avg loss = nan
# iteration 130, using 40 images, avg loss = nan
# iteration 131, using 40 images, avg loss = nan
# iteration 132, using 40 images, avg loss = nan
# iteration 133, using 40 images, avg loss = nan
# iteration 134, using 40 images, avg loss = nan
# iteration 135, using 40 images, avg loss = nan
# iteration 136, using 40 images, avg loss = nan
# iteration 137, using 40 images, avg loss = nan
# iteration 138, using 40 images, avg loss = nan
# iteration 139, using 40 images, avg loss = nan
# iteration 140, using 40 images, avg loss = nan
# iteration 141, using 40 images, avg loss = nan
# iteration 142, using 40 images, avg loss = nan
# iteration 143, using 40 images, avg loss = nan
# iteration 144, using 40 images, avg loss = nan
# iteration 145, using 40 images, avg loss = nan
# iteration 146, using 40 images, avg loss = nan
# iteration 147, using 40 images, avg loss = nan
# iteration 148, using 40 images, avg loss = nan
# iteration 149, using 40 images, avg loss = nan
# iteration 150, using 40 images, avg loss = nan

# %% [markdown]
# If everything's gone right, you should see a converging loss plot below! This shows you the average loss across all 121 images at each iteration of our optimization.

# %%
plot_losses(losses, 150)

# %% [markdown]
# And finally you should see our recovered reconstruction! You'll note that there are some artifacts... but we got a higher resolution reconstruction of the amplitude (look at the details on the hair, grass, or buttons), and an estimate of the phase of the sample.

# %%
show_amplitude_and_phase(*parameters)

# %% [markdown]
# ## Extensions
#
# If you want to continue working on this demo:
#
# 1. The reconstruction above has significant artifacts. Can you play with either the angles of illumination or the optimization to improve these artifacts?
# 2. You can try to [install Chromatix](https://chromatix.readthedocs.io/en/latest/installing/) on your own computer with a bigger GPU and try out your own optimizations at a bigger scale than this simple demo.
